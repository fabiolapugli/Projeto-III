# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Milestone #1
# Entender a base e elas estão conectadas e conteúdo de cada coluna.
# Preparar material com essas informações e gráficos para explicar para outras pessoas

# %% [markdown]
# # BASE 1

# %%
movies = pd.read_csv("C:/Users/rezen/Desktop/Curso Data Science/Módulo 4 - Pandas/Projeto/IMDb movies.csv")
movies
# Out:
#       imdb_title_id                                              title  \
# 0         tt0000574                        The Story of the Kelly Gang
# 1         tt0001892                                     Den sorte drøm
# 2         tt0002101                                          Cleopatra
# 3         tt0002130                                          L'Inferno
# 4         tt0002199  From the Manger to the Cross; or, Jesus of Naz...
# ...             ...                                                ...
# 81268     tt9903716                                             Jessie
# 81269     tt9905412                                              Ottam
# 81270     tt9905462                                          Pengalila
# 81271     tt9911774                          Padmavyuhathile Abhimanyu
# 81272     tt9914286                                  Sokagin Çocuklari
#
#                                           original_title  year date_published  \
# ...

# %%
movies.describe()
# Out:
#                year      duration      avg_vote         votes     metascore  \
# count  81273.000000  81273.000000  81273.000000  8.127300e+04  12722.000000
# mean    1993.007210    100.565981      5.926587  9.421771e+03     55.762695
# std       23.992284     25.320189      1.243315  5.220245e+04     17.757453
# min     1906.000000     40.000000      1.000000  9.900000e+01      1.000000
# 25%     1979.000000     88.000000      5.200000  2.060000e+02     43.000000
# 50%     2002.000000     96.000000      6.100000  4.950000e+02     56.000000
# 75%     2012.000000    108.000000      6.800000  1.865000e+03     69.000000
# max     2019.000000   3360.000000     10.000000  2.159628e+06    100.000000
#
#        reviews_from_users  reviews_from_critics
# count        74196.000000          70286.000000
# mean            43.753194             27.992758
# std            159.903568             58.708764
# min              1.000000              1.000000
# ...

# %%
movies[['duration', 'genre']].groupby ('genre').mean().sort_values('duration')
# Out:
#                                duration
# genre
# Animation, Biography, History      45.0
# Animation, Adventure, Musical      46.0
# Adventure, Sci-Fi, Animation       48.0
# Drama, Family, Action              50.0
# Musical, Animation, Fantasy        52.0
# ...                                 ...
# Adventure, Crime, Sci-Fi          194.5
# Fantasy, Adventure, Action        203.0
# War, Action, Adventure            208.0
# Adventure, Action, Crime          267.0
# Action, Mystery, Crime            302.0
#
# [1264 rows x 1 columns]

# %%
movies['duration'].mean()
# Out:
# 100.56598132221033

# %%
movies.sort_values('duration')

#plt.xticks([75, 100, 125, 150, 175, 200, 225, 250])

#movies['duration'].plot.hist()

List = movies['duration'].tolist()

rangex = [25, 50, 75, 100, 125, 150, 175, 200, 225]

plt.hist(List,rangex)
         
plt.xlabel('duraction')
plt.xticks(rangex)
#plt.yticks([0, 1, 2, 3, 4, 5])

plt.show()

# %%
movies["genre"].value_counts()
# Out:
# Drama                        11809
# Comedy                        7322
# Comedy, Drama                 3822
# Drama, Romance                3252
# Comedy, Romance               2383
#                              ...
# Mystery, Thriller, Action        1
# Fantasy, History, Horror         1
# Action, Thriller, Sci-Fi         1
# Fantasy, Western                 1
# Fantasy, Musical, Mystery        1
# Name: genre, Length: 1264, dtype: int64

# %%
movies2 = movies[(movies['genre'] == 'Drama') | (movies['genre'] == 'Comedy') | (movies['genre'] == 'Comedy, Drama') | (movies["genre"] == 'Drama, Romance') | (movies["genre"] == 'Comedy, Romance')]
                                                                                                                                                  
movies2["genre"].value_counts().plot.pie(autopct='%1.1f%%')

# %%
movies["country"].value_counts()
# Out:
# USA                                               27490
# India                                              5540
# UK                                                 3869
# France                                             2975
# Japan                                              2850
#                                                   ...
# Soviet Union, Italy, Switzerland                      1
# France, Switzerland, West Germany, UK, Hungary        1
# Spain, Portugal, Netherlands                          1
# France, Belgium, Georgia, Switzerland                 1
# Belgium, UK, USA                                      1
# Name: country, Length: 4632, dtype: int64

# %%
movies3 = movies[(movies['country'] == 'USA') | (movies['country'] == 'India') | (movies['country'] == 'UK') | (movies['country'] == 'France') | (movies['country'] == 'Japan')]

movies3['country'].value_counts().plot.pie(autopct='%1.1f%%')

# %%
movies['director'].value_counts()
# Out:
# Michael Curtiz      86
# Jesús Franco        85
# Lloyd Bacon         73
# William Beaudine    69
# John Ford           67
#                     ..
# Samir Tewari         1
# Anne Misawa          1
# Simone Scafidi       1
# Jim Hanon            1
# Matt Danner          1
# Name: director, Length: 32544, dtype: int64

# %%
movies4 = movies[(movies['director'] == 'Michael Curtiz') | (movies['director'] == 'Jesús Franco') | (movies['director'] == 'Lloyd Bacon') | (movies['director'] == 'William Beaudine') | (movies['director'] == 'John Ford')]

movies4["director"].value_counts().plot.bar()

# %%
movies.columns
# Out:
# Index(['imdb_title_id', 'title', 'original_title', 'year', 'date_published',
#        'genre', 'duration', 'country', 'language', 'director', 'writer',
#        'production_company', 'actors', 'description', 'avg_vote', 'votes',
#        'budget', 'usa_gross_income', 'worlwide_gross_income', 'metascore',
#        'reviews_from_users', 'reviews_from_critics'],
#       dtype='object')

# %%
movies['writer'].value_counts()
# Out:
# Jing Wong                                81
# Kuang Ni                                 44
# Woody Allen                              40
# Cheh Chang, Kuang Ni                     32
# Leonardo Benvenuti, Piero De Bernardi    32
#                                          ..
# David Chandler, Harry Brown               1
# John J. McLaughlin, Stephen Rebello       1
# Mircea Burada, Vintilä Corbul             1
# Olivier Dazat, Christian Vincent          1
# Howard Sackler, Howard Sackler            1
# Name: writer, Length: 63335, dtype: int64

# %%
movies5 = movies[(movies['writer'] == 'Jing Wong') | (movies['writer'] == 'Kuang Ni') | (movies['writer'] == 'Woody Allen') | (movies['writer'] == 'Cheh Chang, Kuang Ni') | (movies['writer'] == 'Leonardo Benvenuti, Piero De Bernardi')]
movies5["writer"].value_counts().plot.bar()

# %%
movies['production_company'].value_counts()
# Out:
# Metro-Goldwyn-Mayer (MGM)          1290
# Warner Bros.                       1148
# Columbia Pictures                   898
# Paramount Pictures                  884
# Twentieth Century Fox               866
#                                    ...
# DMK Productions                       1
# Sinehane                              1
# CAPAD                                 1
# Corporate Sucker Films                1
# Hare Brained Scream Productions       1
# Name: production_company, Length: 30122, dtype: int64

# %%
movies6 = movies[(movies['production_company'] == 'Metro-Goldwyn-Mayer (MGM)') | (movies['production_company'] == 'Warner Bros.') | (movies['production_company'] == 'Columbia Pictures') | (movies['production_company'] == 'Paramount Pictures') | (movies['production_company'] == 'Twentieth Century Fox')]
movies6["production_company"].value_counts().plot.bar()

# %% [markdown]
# # Base 2

# %%
names = pd.read_csv("C:/Users/rezen/Desktop/Curso Data Science/Módulo 4 - Pandas/Projeto/IMDb names.csv")
names
# Out:
#        imdb_name_id                   name               birth_name  height  \
# 0         nm0000001           Fred Astaire  Frederic Austerlitz Jr.   177.0
# 1         nm0000002          Lauren Bacall        Betty Joan Perske   174.0
# 2         nm0000003        Brigitte Bardot          Brigitte Bardot   166.0
# 3         nm0000004           John Belushi        John Adam Belushi   173.0
# 4         nm0000005         Ingmar Bergman     Ernst Ingmar Bergman   179.0
# ...             ...                    ...                      ...     ...
# 175710    nm9991131  Charoen Kaithitisuwan    Charoen Kaithitisuwan     NaN
# 175711    nm9991653        Wojciech Rzehak          Wojciech Rzehak     NaN
# 175712    nm9992720       McMagic Cardenas         McMagic Cardenas     NaN
# 175713    nm9992840    Rashaduzzman Shohag      Rashaduzzman Shohag     NaN
# 175714    nm9992999         William Plyler           William Plyler     NaN
#
# ...

# %% [markdown]
# # Base 3

# %%
ratings = pd.read_csv("C:/Users/rezen/Desktop/Curso Data Science/Módulo 4 - Pandas/Projeto/IMDb ratings.csv")
ratings
# Out:
#       imdb_title_id  weighted_average_vote  total_votes  mean_vote  \
# 0         tt0000574                    6.1          537        6.3
# 1         tt0001892                    5.9          171        6.1
# 2         tt0002101                    5.2          420        5.2
# 3         tt0002130                    7.0         2019        6.9
# 4         tt0002199                    5.7          438        5.8
# ...             ...                    ...          ...        ...
# 81268     tt9903716                    7.2          219        8.1
# 81269     tt9905412                    7.8          510        7.8
# 81270     tt9905462                    8.4          604        8.1
# 81271     tt9911774                    8.4          369        8.2
# 81272     tt9914286                    7.2          190        9.5
#
#        median_vote  votes_10  votes_9  votes_8  votes_7  votes_6  ...  \
# 0              6.0        54       17       55      121      122  ...
# ...

# %%
ratings['total_votes']
# Out:
# 0         537
# 1         171
# 2         420
# 3        2019
# 4         438
#          ...
# 81268     219
# 81269     510
# 81270     604
# 81271     369
# 81272     190
# Name: total_votes, Length: 81273, dtype: int64

# %%
ratings.describe()
# Out:
#        weighted_average_vote   total_votes     mean_vote   median_vote  \
# count           81273.000000  8.127300e+04  81273.000000  81273.000000
# mean                5.926587  9.421771e+03      6.259578      6.304055
# std                 1.243315  5.220245e+04      1.161615      1.492902
# min                 1.000000  9.900000e+01      1.000000      1.000000
# 25%                 5.200000  2.060000e+02      5.600000      6.000000
# 50%                 6.100000  4.950000e+02      6.400000      7.000000
# 75%                 6.800000  1.865000e+03      7.100000      7.000000
# max                10.000000  2.159628e+06     10.000000     10.000000
#
#            votes_10        votes_9        votes_8        votes_7  \
# count  8.127300e+04   81273.000000   81273.000000   81273.000000
# mean   1.222871e+03    1192.843527    2019.657365    2076.640545
# std    1.221412e+04   11427.311637   13386.328821   10384.089767
# min    0.000000e+00       0.000000       0.000000       0.000000
# ...

# %% [markdown]
# # Base 4

# %%
title_principals = pd.read_csv("C:/Users/rezen/Desktop/Curso Data Science/Módulo 4 - Pandas/Projeto/IMDb title_principals.csv")
title_principals
# Out:
#        imdb_title_id  ordering imdb_name_id         category       job  \
# 0          tt0000574         1    nm0846887          actress       NaN
# 1          tt0000574         2    nm0846894            actor       NaN
# 2          tt0000574         3    nm3002376            actor       NaN
# 3          tt0000574         4    nm0170118          actress       NaN
# 4          tt0000574         5    nm0846879         director       NaN
# ...              ...       ...          ...              ...       ...
# 377843     tt9903716         5   nm10532693         director       NaN
# 377844     tt9903716         6   nm10531260         producer  producer
# 377845     tt9903716         7    nm6044359         composer       NaN
# 377846     tt9903716         8   nm10532695  cinematographer       NaN
# 377847     tt9903716         9    nm9492020           editor       NaN
#
#                characters
# 0          ["Kate Kelly"]
# 1       ["School Master"]
# 2          ["Steve Hart"]
# ...

# %%
#Dado um ano, mostre os top 25 melhores filmes, suas notas e seus gêneros;

year = int(input())

filt = movies[['imdb_title_id','title','year','genre','avg_vote']]
filt = filt[(filt['year'] == year)].sort_values('avg_vote', ascending=False).head(25)

filt
# Out:
# 2000
#       imdb_title_id                                         title  year  \
# 38186     tt0270321                        Dr. Babasaheb Ambedkar  2000
# 38235     tt0271383                         O Auto da Compadecida  2000
# 33501     tt0172495                                     Gladiator  2000
# 42789     tt0375093                             Srabon Megher Din  2000
# 35417     tt0209144                                       Memento  2000
# 33872     tt0180093                           Requiem for a Dream  2000
# 35368     tt0208092                                        Snatch  2000
# 36702     tt0242256                                 Alai Payuthey  2000
# 36901     tt0245929                                  Guizi lai le  2000
# 36711     tt0242519                                    Hera Pheri  2000
# 37103     tt0249241                        Werckmeister harmóniák  2000
# 36798     tt0244316                                         Yi yi  2000
# ...
